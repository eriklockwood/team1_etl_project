# %%
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password

# %% [markdown]
# # Step 1. Store IMDb csv into a Pandas DataFrame

# %%
#read IMBD Movies excel file
movies_file = "../etl_project_data/IMDb movies.csv"
movies_data_df = pd.read_csv(movies_file)
movies_data_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
#filter data from 2000 to 2019
movies_data_df.sort_values(by=['year'], ascending=True, inplace= True)
movies_filtered= movies_data_df[~(movies_data_df['year'] < 2000)]
movies_filtered.tail()
# Out:
#       imdb_title_id                   title          original_title  year  \
# 80499     tt8589474            Purity Falls            Purity Falls  2019
# 80883     tt9056192             Zombi Child             Zombi Child  2019
# 80495     tt8585940  The Utah Cabin Murders  The Utah Cabin Murders  2019
# 81122     tt9493708                Underdog                Underdog  2019
# 81272     tt9914286       Sokagin Çocuklari       Sokagin Çocuklari  2019
#
#       date_published                 genre  duration country  \
# 80499     2019-07-20              Thriller        90     USA
# 80883     2019-06-12               Fantasy       103  France
# 80495     2019-09-03         Crime, Horror        85      UK
# 81122     2019-01-18  Action, Drama, Sport       116  Poland
# 81272     2019-03-15         Drama, Family        98  Turkey
#
#                        language           director  ...  \
# 80499                   English          Sam Irvin  ...
# 80883  French, Haitian, English   Bertrand Bonello  ...
# 80495                   English       Andrew Jones  ...
# 81122                    Polish    Maciej Kawulski  ...
# 81272                   Turkish  Ahmet Faik Akinci  ...
#
#                                                   actors  \
# 80499  Kristanna Loken, Olivia d'Abo, Beth Broderick,...
# 80883  Louise Labeque, Wislanda Louimat, Katiana Milf...
# 80495  Dennis Farrin, Tiffany Ceri, Derek Nelson, Eri...
# 81122  Eryk Lubos, Mamed Khalidov, Aleksandra Poplaws...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
#
#                                              description avg_vote votes  \
# 80499  After the tragic death of her husband, a mothe...      5.3   161
# 80883  Haiti, 1962. A man is brought back from the de...      6.2   533
# 80495  Two sisters fight for survival when masked int...      3.0   231
# 81122                                                NaN      5.7   212
# 81272                                                NaN      7.2   190
#
#           budget  usa_gross_income worlwide_gross_income metascore  \
# 80499        NaN               NaN                   NaN       NaN
# 80883        NaN               NaN              $ 174508      73.0
# 80495  $ 1000000               NaN                   NaN       NaN
# 81122        NaN               NaN                   NaN       NaN
# 81272        NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 80499                4.0                   1.0
# 80883                3.0                  30.0
# 80495               17.0                   NaN
# 81122                1.0                   1.0
# 81272                NaN                   NaN
#
# [5 rows x 22 columns]

# %%
#filtering desirable columns
select_imdb_movies_df = movies_filtered[['title', 'year', 'duration', 'budget', 'worlwide_gross_income','language','country']]
select_imdb_movies_df.head(50)
# Out:
#                                                    title  year  duration  \
# 32874                                             Trixie  2000       116
# 32948                                    Bless the Child  2000       107
# 35035                                  The Last Producer  2000        90
# 35036                   Lost in the Pershing Point Hotel  2000       107
# 38686                                     Fatal Conflict  2000        92
# 36155                                       Bear with Me  2000        96
# 47041                        Vecas pagastmajas misterija  2000       105
# 34983                                 The House of Mirth  2000       135
# 38733                                        Devadoothan  2000       158
# 32908                            La parenthèse enchantée  2000        88
# 36880                                      Amores perros  2000       154
# 47250    Shirley Pimple in the John Wayne Temple of Doom  2000        90
# 36140                                      Plata quemada  2000       125
# 30722                                              Bruno  2000       108
# 35076                                         DoppelPack  2000        88
# 36138               Operation Delta Force 5: Random Fire  2000        91
# 32907                                       The Operator  2000       102
# 34980                                    The Golden Bowl  2000       130
# 35073                                        Tribulation  2000        95
# 32902                                  The Magic Pudding  2000        80
# 36881                                              Artie  2000        89
# 38771                                     Ostatnia misja  2000       102
# 38723                                           Bawandar  2000       125
# 35029                                             House!  2000        90
# 35049                                     Just One Night  2000        90
# 60964                                   Dastha-ye aloode  2000       103
# 36889                                           Stand-by  2000       125
# 36891                                      Chunhyangdyun  2000       120
# 32894                                         Hanging Up  2000        94
# 35047                                      Rent a Friend  2000        90
# 38707  Daehakno-yeseo maechoon-hadaka tomaksalhae dan...  2000        60
# 31765                                 No Quarto da Vanda  2000       171
# 36886                                     Chal Mere Bhai  2000       136
# 46620                                           Yuvakudu  2000       145
# 38716                             Anakiseuteu Anarchists  2000       104
# 36894                                              Drift  2000        86
# 35018                                           Blowback  2000        91
# 32947                                          The Beach  2000       119
# 36916                                               Maze  2000        97
# 32938                                          The Debut  2000        94
# 30731                         The Elf Who Didn't Believe  2000        90
# 32883                                             Kasbah  2000        99
# 38755                                       Keizoku/eiga  2000       119
# 36919                                             Svadba  2000       114
# 36152                                   We All Fall Down  2000        92
# 38753                         The Journey of Jared Price  2000        95
# 36898                                      Ftina tsigara  2000        85
# 31749                                   It Had to Be You  2000        96
# 36143                                          Le secret  2000       107
# 36901                                       Guizi lai le  2000       139
#
#             budget worlwide_gross_income  \
# 32874          NaN              $ 295683
# 32948   $ 65000000            $ 40443010
# 35035          NaN                   NaN
# 35036          NaN                   NaN
# 38686          NaN                   NaN
# 36155          NaN                   NaN
# 47041          NaN                   NaN
# 34983   $ 10000000             $ 5164404
# 38733          NaN                   NaN
# 32908          NaN                   NaN
# 36880    $ 2000000            $ 20908467
# 47250  CAD 1500000                   NaN
# 36140          NaN              $ 190075
# 30722   $ 10000000                   NaN
# 35076          NaN                   NaN
# 36138          NaN                   NaN
# 32907    $ 1500000                   NaN
# 34980   $ 15000000             $ 5753678
# 35073          NaN                   NaN
# 32902          NaN              $ 368626
# 36881    $ 1000000                   NaN
# 38771          NaN                   NaN
# 38723          NaN                $ 3779
# 35029          NaN                   NaN
# 35049          NaN                   NaN
# 60964          NaN                   NaN
# 36889          NaN                   NaN
# 36891          NaN                   NaN
# 32894   $ 60000000            $ 51880044
# 35047          NaN                   NaN
# 38707          NaN                   NaN
# 31765          NaN                $ 2912
# 36886          NaN              $ 199227
# 46620          NaN                   NaN
# 38716          NaN                   NaN
# 36894          NaN                   NaN
# 35018          NaN                   NaN
# 32947   $ 50000000           $ 144056873
# 36916          NaN               $ 26041
# 32938          NaN             $ 1745778
# 30731          NaN                   NaN
# 32883          NaN                   NaN
# 38755          NaN                   NaN
# 36919          NaN                   NaN
# 36152          NaN                   NaN
# 38753      $ 30000                   NaN
# 36898          NaN                   NaN
# 31749   $ 10000000                   NaN
# 36143          NaN              $ 166721
# 36901          NaN               $ 18944
#
#                                       language                         country
# 32874                                  English                             USA
# 32948                                  English                    USA, Germany
# 35035                                  English                             USA
# 35036                                  English                             USA
# 38686                                  English          Czech Republic, Canada
# 36155                                  English                          Canada
# 47041                                  Latvian                          Latvia
# 34983                  English, French, German        UK, USA, France, Germany
# 38733                                Malayalam                           India
# 32908                                   French                          France
# 36880                                  Spanish                          Mexico
# 47250                                  English                          Canada
# 36140                                  Spanish       Argentina, Spain, Uruguay
# 30722                                  English                             USA
# 35076                                   German                         Germany
# 36138                                  English                             USA
# 32907                                  English                             USA
# 34980                                  English                 USA, France, UK
# 35073                                  English                          Canada
# 32902                                  English                       Australia
# 36881                                  English                             USA
# 38771          Polish, French, English, Arabic                          Poland
# 38723               Hindi, Rajasthani, English                           India
# 35029                                  English                              UK
# 35049                                  English                             USA
# 60964                                  Persian                            Iran
# 36889                                   French                          France
# 36891                                   Korean                     South Korea
# 32894                                  English                    Germany, USA
# 35047                                    Dutch                     Netherlands
# 38707                                   Korean                     South Korea
# 31765                               Portuguese  Portugal, Germany, Switzerland
# 36886                                    Hindi                           India
# 46620                                   Telugu                           India
# 38716                                   Korean              South Korea, China
# 36894                                  English                          Canada
# 35018                                  English                     Canada, USA
# 32947  English, French, Swedish, Thai, Serbian                         USA, UK
# 36916                                  English                             USA
# 32938               English, Tagalog, Filipino                             USA
# 30731                                  English                             USA
# 32883                                  Spanish                Spain, Argentina
# 38755                                 Japanese                           Japan
# 36919                                  Russian         France, Russia, Germany
# 36152                                  English                          Canada
# 38753                                  English                             USA
# 36898                           Greek, English                          Greece
# 31749                                  English                             USA
# 36143                          French, English                          France
# 36901      Mandarin, Japanese, English, French                           China

# %%
#create movie_id primary key
select_imdb_movies_df['movie_id'] = range(1, len(select_imdb_movies_df)+1)
select_imdb_movies_df.set_index('movie_id', inplace=True)
select_imdb_movies_df.tail()
# Out:
# <ipython-input-60-3c4c15fdae2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select_imdb_movies_df['movie_id'] = range(1, len(select_imdb_movies_df)+1)
#                             title  year  duration        budget  \
# movie_id
# 43877                       Artik  2019        78           NaN
# 43878                   Kaaviyyan  2019       109           NaN
# 43879                See You Soon  2019       107           NaN
# 43880     Mirreyes contra Godinez  2019       109  MXN 28000000
# 43881           Sokagin Çocuklari  2019        98           NaN
#
#          worlwide_gross_income language country
# movie_id
# 43877                      NaN      NaN     NaN
# 43878                      NaN    Tamil   India
# 43879                 $ 277126  English     USA
# 43880               $ 11940579  Spanish  Mexico
# 43881                   $ 2833  Turkish  Turkey

# %% [markdown]
# # Step 2.  "lang"  and lang_ movies tables

# %%
#selecting only language and title column
language_df = select_imdb_movies_df[["language","title"]].copy()
language_df.rename(columns={"language":"name"}, inplace= True)
language_df.tail(15)
# Out:
#                                               name                    title
# movie_id
# 43867                                      Turkish             Çat Kapi Ask
# 43868                                      English                    Joker
# 43869     Telugu, Hindi, Tamil, Kannada, Malayalam  Sye Raa Narasimha Reddy
# 43870                                      English                  Teacher
# 43871                                        Latin              Il primo re
# 43872                                       German                     Lara
# 43873                                      English                #Followme
# 43874                                      English                  Deadcon
# 43875                                        Hindi    Student of the Year 2
# 43876                              English, French                Lucky Day
# 43877                                          NaN                    Artik
# 43878                                        Tamil                Kaaviyyan
# 43879                                      English             See You Soon
# 43880                                      Spanish  Mirreyes contra Godinez
# 43881                                      Turkish        Sokagin Çocuklari

# %%
# normalize laguage names
language_normalized= language_df.set_index('title').name.str.split(',', expand=True).stack().reset_index('title')
language_normalized.head()
# Out:
#                               title        0
# 0                            Trixie  English
# 0                   Bless the Child  English
# 0                 The Last Producer  English
# 0  Lost in the Pershing Point Hotel  English
# 0                    Fatal Conflict  English

# %%
# renaming 0 to "name"
language_renamed= language_normalized.rename(columns={0:"name"}).copy()
language_renamed= language_renamed["name"].to_frame()
language_renamed
# Out:
#        name
# 0   English
# 0   English
# 0   English
# 0   English
# 0   English
# ..      ...
# 1    French
# 0     Tamil
# 0   English
# 0   Spanish
# 0   Turkish
#
# [58171 rows x 1 columns]

# %%
#unique languages names

lang_df= language_renamed.groupby(["name"]).count().copy()
lang_df= lang_df.reset_index()
lang_df
# Out:
#             name
# 0      Abkhazian
# 1     Aboriginal
# 2         Acholi
# 3      Afrikaans
# 4           Akan
# ..           ...
# 379        Xhosa
# 380        Yakut
# 381      Yiddish
# 382       Yoruba
# 383         Zulu
#
# [384 rows x 1 columns]

# %%
#generate a unique id and rename it as lang_id
lang_df["id"] = lang_df.index + 1
lang_df.rename(columns={"id":"lang_id"}, inplace=True)
lang_df
# Out:
#             name  lang_id
# 0      Abkhazian        1
# 1     Aboriginal        2
# 2         Acholi        3
# 3      Afrikaans        4
# 4           Akan        5
# ..           ...      ...
# 379        Xhosa      380
# 380        Yakut      381
# 381      Yiddish      382
# 382       Yoruba      383
# 383         Zulu      384
#
# [384 rows x 2 columns]

# %%
#reorganizing columns
lang_table= lang_df[["lang_id","name"]]
lang_table
# Out:
#      lang_id         name
# 0          1    Abkhazian
# 1          2   Aboriginal
# 2          3       Acholi
# 3          4    Afrikaans
# 4          5         Akan
# ..       ...          ...
# 379      380        Xhosa
# 380      381        Yakut
# 381      382      Yiddish
# 382      383       Yoruba
# 383      384         Zulu
#
# [384 rows x 2 columns]

# %%
#reset movie_id
imdb_movies_df= select_imdb_movies_df.reset_index()
imdb_movies_df
# Out:
#        movie_id                             title  year  duration  \
# 0             1                            Trixie  2000       116
# 1             2                   Bless the Child  2000       107
# 2             3                 The Last Producer  2000        90
# 3             4  Lost in the Pershing Point Hotel  2000       107
# 4             5                    Fatal Conflict  2000        92
# ...         ...                               ...   ...       ...
# 43876     43877                             Artik  2019        78
# 43877     43878                         Kaaviyyan  2019       109
# 43878     43879                      See You Soon  2019       107
# 43879     43880           Mirreyes contra Godinez  2019       109
# 43880     43881                 Sokagin Çocuklari  2019        98
#
#              budget worlwide_gross_income language                 country
# 0               NaN              $ 295683  English                     USA
# 1        $ 65000000            $ 40443010  English            USA, Germany
# 2               NaN                   NaN  English                     USA
# 3               NaN                   NaN  English                     USA
# 4               NaN                   NaN  English  Czech Republic, Canada
# ...             ...                   ...      ...                     ...
# 43876           NaN                   NaN      NaN                     NaN
# 43877           NaN                   NaN    Tamil                   India
# 43878           NaN              $ 277126  English                     USA
# 43879  MXN 28000000            $ 11940579  Spanish                  Mexico
# 43880           NaN                $ 2833  Turkish                  Turkey
#
# [43881 rows x 8 columns]

# %%
# taking one more time language_normalized df, to merge with select_imdb_movies_df
language_normalized
# Out:
#                                title        0
# 0                             Trixie  English
# 0                    Bless the Child  English
# 0                  The Last Producer  English
# 0   Lost in the Pershing Point Hotel  English
# 0                     Fatal Conflict  English
# ..                               ...      ...
# 1                          Lucky Day   French
# 0                          Kaaviyyan    Tamil
# 0                       See You Soon  English
# 0            Mirreyes contra Godinez  Spanish
# 0                  Sokagin Çocuklari  Turkish
#
# [58171 rows x 2 columns]

# %%
#merge dataframes on "title"
lang_movies_merge= pd.merge(imdb_movies_df,language_normalized, on="title").copy()
lang_movies_merge= lang_movies_merge[["movie_id","title",0]]
lang_movies_merge.tail(15)
# Out:
#        movie_id                    title           0
# 63183     43869  Sye Raa Narasimha Reddy       Tamil
# 63184     43869  Sye Raa Narasimha Reddy     Kannada
# 63185     43869  Sye Raa Narasimha Reddy   Malayalam
# 63186     43870                  Teacher     English
# 63187     43871              Il primo re       Latin
# 63188     43872                     Lara      German
# 63189     43873                #Followme     English
# 63190     43874                  Deadcon     English
# 63191     43875    Student of the Year 2       Hindi
# 63192     43876                Lucky Day     English
# 63193     43876                Lucky Day      French
# 63194     43878                Kaaviyyan       Tamil
# 63195     43879             See You Soon     English
# 63196     43880  Mirreyes contra Godinez     Spanish
# 63197     43881        Sokagin Çocuklari     Turkish

# %%
#rename column 0 to "name"

lang_movies_merge.rename(columns={0:"name"}, inplace= True)
lang_movies_merge
# Out:
#        movie_id                             title     name
# 0             1                            Trixie  English
# 1             2                   Bless the Child  English
# 2             3                 The Last Producer  English
# 3             4  Lost in the Pershing Point Hotel  English
# 4             5                    Fatal Conflict  English
# ...         ...                               ...      ...
# 63193     43876                         Lucky Day   French
# 63194     43878                         Kaaviyyan    Tamil
# 63195     43879                      See You Soon  English
# 63196     43880           Mirreyes contra Godinez  Spanish
# 63197     43881                 Sokagin Çocuklari  Turkish
#
# [63198 rows x 3 columns]

# %%
# merge lang_movies_merge with lang_table on "name", to ensure lang_id and movie_id relation
lang_movies_id_merge= pd.merge(lang_movies_merge,lang_table, on="name")
lang_movies_id_merge
# Out:
#        movie_id                             title     name  lang_id
# 0             1                            Trixie  English      267
# 1             2                   Bless the Child  English      267
# 2             3                 The Last Producer  English      267
# 3             4  Lost in the Pershing Point Hotel  English      267
# 4             5                    Fatal Conflict  English      267
# ...         ...                               ...      ...      ...
# 63193     40647                The Burial Of Kojo     Akan      236
# 63194     41596                   SGaawaay K'uuna    Haida      282
# 63195     42303                 Pájaros de verano    Wayuu      377
# 63196     42706                              Evge    Tatar      366
# 63197     43270                        Atlantique    Wolof      379
#
# [63198 rows x 4 columns]

# %%
#clean lang_moies_id_merge df
lang_movies_table= lang_movies_id_merge[["movie_id", "lang_id"]]
lang_movies_table.tail()
# Out:
#        movie_id  lang_id
# 63193     40647      236
# 63194     41596      282
# 63195     42303      377
# 63196     42706      366
# 63197     43270      379

# %% [markdown]
# # Step 3 "country" and "movie_country" tables

# %%
#selecting only country and title column
country_df = movies_filtered[["country","title"]].copy()
country_df.rename(columns={"country":"name"}, inplace= True)
country_df
# Out:
#                          name                             title
# 32874                     USA                            Trixie
# 32948            USA, Germany                   Bless the Child
# 35035                     USA                 The Last Producer
# 35036                     USA  Lost in the Pershing Point Hotel
# 38686  Czech Republic, Canada                    Fatal Conflict
# ...                       ...                               ...
# 78770                     NaN                             Artik
# 78735                   India                         Kaaviyyan
# 78707                     USA                      See You Soon
# 78856                  Mexico           Mirreyes contra Godinez
# 81272                  Turkey                 Sokagin Çocuklari
#
# [43881 rows x 2 columns]

# %%
# normalize laguage names
country_normalized= country_df.set_index('title').name.str.split(',', expand=True).stack().reset_index('title')
country_normalized
# Out:
#                                title         0
# 0                             Trixie       USA
# 0                    Bless the Child       USA
# 1                    Bless the Child   Germany
# 0                  The Last Producer       USA
# 0   Lost in the Pershing Point Hotel       USA
# ..                               ...       ...
# 1                          Lucky Day    Canada
# 0                          Kaaviyyan     India
# 0                       See You Soon       USA
# 0            Mirreyes contra Godinez    Mexico
# 0                  Sokagin Çocuklari    Turkey
#
# [57854 rows x 2 columns]

# %%
# renaming 0 to "name"
country_renamed= country_normalized.rename(columns={0:"name"}).copy()
country_renamed= country_renamed["name"].to_frame()
country_renamed
# Out:
#         name
# 0        USA
# 0        USA
# 1    Germany
# 0        USA
# 0        USA
# ..       ...
# 1     Canada
# 0      India
# 0        USA
# 0     Mexico
# 0     Turkey
#
# [57854 rows x 1 columns]

# %%
#unique country names

countr_df= country_renamed.groupby(["name"]).count().copy()
countr_df= countr_df.reset_index()
countr_df
# Out:
#                      name
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
# ..                    ...
# 300  United Arab Emirates
# 301               Uruguay
# 302             Venezuela
# 303               Vietnam
# 304                 Yemen
#
# [305 rows x 1 columns]

# %%
#generate a unique id and rename it as lang_id
countr_df["id"] = countr_df.index + 1
countr_df.rename(columns={"id":"country_id"}, inplace=True)
countr_df
# Out:
#                      name  country_id
# 0             Afghanistan           1
# 1                 Albania           2
# 2                 Algeria           3
# 3                 Andorra           4
# 4                  Angola           5
# ..                    ...         ...
# 300  United Arab Emirates         301
# 301               Uruguay         302
# 302             Venezuela         303
# 303               Vietnam         304
# 304                 Yemen         305
#
# [305 rows x 2 columns]

# %%
#reorganizing columns
country_table= countr_df[["country_id","name"]]
country_table
# Out:
#      country_id                  name
# 0             1           Afghanistan
# 1             2               Albania
# 2             3               Algeria
# 3             4               Andorra
# 4             5                Angola
# ..          ...                   ...
# 300         301  United Arab Emirates
# 301         302               Uruguay
# 302         303             Venezuela
# 303         304               Vietnam
# 304         305                 Yemen
#
# [305 rows x 2 columns]

# %%
#create movie_country join table
# taking one more time country_normalized df, to merge with select_imdb_movies_df
country_normalized
# Out:
#                                title         0
# 0                             Trixie       USA
# 0                    Bless the Child       USA
# 1                    Bless the Child   Germany
# 0                  The Last Producer       USA
# 0   Lost in the Pershing Point Hotel       USA
# ..                               ...       ...
# 1                          Lucky Day    Canada
# 0                          Kaaviyyan     India
# 0                       See You Soon       USA
# 0            Mirreyes contra Godinez    Mexico
# 0                  Sokagin Çocuklari    Turkey
#
# [57854 rows x 2 columns]

# %%
#merge dataframes on "title"
countr_movie_merge= pd.merge(imdb_movies_df,country_normalized, on="title").copy()
countr_movie_merge= countr_movie_merge[["movie_id","title",0]]
countr_movie_merge.tail(15)
# Out:
#        movie_id                    title         0
# 62917     43869  Sye Raa Narasimha Reddy     India
# 62918     43870                  Teacher       USA
# 62919     43871              Il primo re     Italy
# 62920     43871              Il primo re   Belgium
# 62921     43872                     Lara   Germany
# 62922     43873                #Followme        UK
# 62923     43873                #Followme       USA
# 62924     43874                  Deadcon       USA
# 62925     43875    Student of the Year 2     India
# 62926     43876                Lucky Day    France
# 62927     43876                Lucky Day    Canada
# 62928     43878                Kaaviyyan     India
# 62929     43879             See You Soon       USA
# 62930     43880  Mirreyes contra Godinez    Mexico
# 62931     43881        Sokagin Çocuklari    Turkey

# %%
#rename column 0 to "name"

countr_movie_merge.rename(columns={0:"name"}, inplace= True)
countr_movie_merge
# Out:
#        movie_id                             title      name
# 0             1                            Trixie       USA
# 1             2                   Bless the Child       USA
# 2             2                   Bless the Child   Germany
# 3             3                 The Last Producer       USA
# 4             4  Lost in the Pershing Point Hotel       USA
# ...         ...                               ...       ...
# 62927     43876                         Lucky Day    Canada
# 62928     43878                         Kaaviyyan     India
# 62929     43879                      See You Soon       USA
# 62930     43880           Mirreyes contra Godinez    Mexico
# 62931     43881                 Sokagin Çocuklari    Turkey
#
# [62932 rows x 3 columns]

# %%
# merge countr_movie_merge with country_table on "name", to ensure lang_id and movie_id relation
countr_movie_id_merge= pd.merge(countr_movie_merge,country_table, on="name")
countr_movie_id_merge
# Out:
#        movie_id                             title          name  country_id
# 0             1                            Trixie           USA         298
# 1             2                   Bless the Child           USA         298
# 2             3                 The Last Producer           USA         298
# 3             4  Lost in the Pershing Point Hotel           USA         298
# 4            14                             Bruno           USA         298
# ...         ...                               ...           ...         ...
# 62927     42094                   Kaminnyy khrest  Soviet Union         282
# 62928     42514                You Will Die at 20         Sudan         285
# 62929     42821   Tabi no Owari Sekai no Hajimari    Uzbekistan         157
# 62930     43445                            Zayana          Oman         256
# 62931     43800    The Boy Who Harnessed the Wind        Malawi          90
#
# [62932 rows x 4 columns]

# %%
#clean countr_movie_id_merge df
countr_movie_table= countr_movie_id_merge[["movie_id", "country_id"]]
countr_movie_table
# Out:
#        movie_id  country_id
# 0             1         298
# 1             2         298
# 2             3         298
# 3             4         298
# 4            14         298
# ...         ...         ...
# 62927     42094         282
# 62928     42514         285
# 62929     42821         157
# 62930     43445         256
# 62931     43800          90
#
# [62932 rows x 2 columns]

# %% [markdown]
# # Step 4. Create Ratings Table

# %%
# loading ratings source csv
rating_source = "../etl_project_data/MoviesOnStreamingPlatforms_updated.csv"
rating_source_df = pd.read_csv(rating_source)
rating_source_df
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87%        1     0            0        0     0
# 1                 87%        1     0            0        0     0
# 2                 84%        1     0            0        0     0
# 3                 96%        1     0            0        0     0
# 4                 97%        1     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16739             NaN        0     0            0        1     0
# 16740             NaN        0     0            0        1     0
# 16741             NaN        0     0            0        1     0
# 16742             NaN        0     0            0        1     0
# 16743             NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
#rename movie_title to title
rating_source_df.rename(columns={"Title":"title"}, inplace = True)

# %%
#Removing "%" string from "Rotten Tomatoes" Column
rating_source_df["Rotten Tomatoes"]= rating_source_df["Rotten Tomatoes"].str.replace('[^\d\.]', '').astype(float)
rating_source_df
# Out:
#        Unnamed: 0     ID                           title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87.0        1     0            0        0     0
# 1                 87.0        1     0            0        0     0
# 2                 84.0        1     0            0        0     0
# 3                 96.0        1     0            0        0     0
# 4                 97.0        1     0            1        0     0
# ...                ...      ...   ...          ...      ...   ...
# 16739              NaN        0     0            0        1     0
# 16740              NaN        0     0            0        1     0
# 16741              NaN        0     0            0        1     0
# 16742              NaN        0     0            0        1     0
# 16743              NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
#create a fraction for Rotten Tomatoes Column
rating_source_df["Rotten Tomatoes"]= rating_source_df["Rotten Tomatoes"]/100
rating_source_df
# Out:
#        Unnamed: 0     ID                           title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 0.87        1     0            0        0     0
# 1                 0.87        1     0            0        0     0
# 2                 0.84        1     0            0        0     0
# 3                 0.96        1     0            0        0     0
# 4                 0.97        1     0            1        0     0
# ...                ...      ...   ...          ...      ...   ...
# 16739              NaN        0     0            0        1     0
# 16740              NaN        0     0            0        1     0
# 16741              NaN        0     0            0        1     0
# 16742              NaN        0     0            0        1     0
# 16743              NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
#upload movie "original database table model"
movie_table_path = "Resources/movie_output2.csv"
movies_table_df = pd.read_csv(movie_table_path)
movies_table_df
# Out:
#        Unnamed: 0                             title  year  duration  \
# 0           32874                            Trixie  2000       116
# 1           32948                   Bless the Child  2000       107
# 2           35035                 The Last Producer  2000        90
# 3           35036  Lost in the Pershing Point Hotel  2000       107
# 4           38686                    Fatal Conflict  2000        92
# ...           ...                               ...   ...       ...
# 43876       78770                             Artik  2019        78
# 43877       78735                         Kaaviyyan  2019       109
# 43878       78707                      See You Soon  2019       107
# 43879       78856           Mirreyes contra Godinez  2019       109
# 43880       81272                 Sokagin Çocuklari  2019        98
#
#              budget  worlwide_gross_income imdb_title_id  movie_id
# 0               NaN               295683.0     tt0162711         1
# 1        $ 65000000             40443010.0     tt0163983         2
# 2               NaN                    NaN     tt0201726         3
# 3               NaN                    NaN     tt0201737         4
# 4               NaN                    NaN     tt0279809         5
# ...             ...                    ...           ...       ...
# 43876           NaN                    NaN     tt7246106     43877
# 43877           NaN                    NaN     tt7225434     43878
# 43878           NaN               277126.0     tt7216068     43879
# 43879  MXN 28000000             11940579.0     tt7294400     43880
# 43880           NaN                 2833.0     tt9914286     43881
#
# [43881 rows x 8 columns]

# %%
# select useful columns
movie_table = movies_table_df[["title","year","duration","budget","worlwide_gross_income","imdb_title_id","movie_id"]]
movie_table.tail(15)
# Out:
#                          title  year  duration         budget  \
# 43866             Çat Kapi Ask  2019        92    TRL 1500000
# 43867                    Joker  2019       122     $ 55000000
# 43868  Sye Raa Narasimha Reddy  2019       167            NaN
# 43869                  Teacher  2019       100            NaN
# 43870              Il primo re  2019       123    EUR 8000000
# 43871                     Lara  2019        98            NaN
# 43872                #Followme  2019        90     GBP 300000
# 43873                  Deadcon  2019        78       $ 100000
# 43874    Student of the Year 2  2019       146  INR 800000000
# 43875                Lucky Day  2019        99      $ 5600000
# 43876                    Artik  2019        78            NaN
# 43877                Kaaviyyan  2019       109            NaN
# 43878             See You Soon  2019       107            NaN
# 43879  Mirreyes contra Godinez  2019       109   MXN 28000000
# 43880        Sokagin Çocuklari  2019        98            NaN
#
#        worlwide_gross_income imdb_title_id  movie_id
# 43866                34417.0     tt7287656     43867
# 43867            995064593.0     tt7286456     43868
# 43868               682418.0     tt7283064     43869
# 43869                    NaN     tt7281538     43870
# 43870              2440478.0     tt7278824     43871
# 43871                    NaN     tt7275830     43872
# 43872                    NaN     tt7272948     43873
# 43873                    NaN     tt7262990     43874
# 43874              1635907.0     tt7255568     43875
# 43875                52369.0     tt7248248     43876
# 43876                    NaN     tt7246106     43877
# 43877                    NaN     tt7225434     43878
# 43878               277126.0     tt7216068     43879
# 43879             11940579.0     tt7294400     43880
# 43880                 2833.0     tt9914286     43881

# %%
# merge rating_source_df and movie_table
rating_movie_merged = pd.merge(movie_table, rating_source_df, on ="title")
rating_movie_merged
# Out:
#                         title  year  duration      budget  \
# 0             Bless the Child  2000       107  $ 65000000
# 1              Fatal Conflict  2000        92         NaN
# 2                Bear with Me  2000        96         NaN
# 3                       Bruno  2000       108  $ 10000000
# 4                 Tribulation  2000        95         NaN
# ...                       ...   ...       ...         ...
# 6651               Saving Zoë  2019        95         NaN
# 6652               Santa Girl  2019        90         NaN
# 6653  Svaha: The Sixth Finger  2019       122         NaN
# 6654              Oh, Ramona!  2019       109         NaN
# 6655                  Deadcon  2019        78    $ 100000
#
#       worlwide_gross_income imdb_title_id  movie_id  Unnamed: 0     ID  Year  \
# 0                40443010.0     tt0163983         2        7339   7340  2000
# 1                       NaN     tt0279809         5       14891  14892  2000
# 2                       NaN     tt0228054         6       13446  13447  2000
# 3                       NaN     tt0123003        14        6738   6739  2000
# 4                       NaN     tt0202236        19        8798   8799  2000
# ...                     ...           ...       ...         ...    ...   ...
# 6651                    NaN     tt7319822     43855        2208   2209  2019
# 6652                    NaN     tt7315570     43859        2441   2442  2019
# 6653             17607783.0     tt7299298     43864        1656   1657  2019
# 6654              1200582.0     tt7200946     43865        2108   2109  2019
# 6655                    NaN     tt7262990     43874        2714   2715  2019
#
#       ... Netflix  Hulu  Prime Video  Disney+  Type          Directors  \
# 0     ...       0     0            1        0     0      Chuck Russell
# 1     ...       0     0            1        0     0   Lloyd A. Simandl
# 2     ...       0     0            1        0     0        Paul Ziller
# 3     ...       0     0            1        0     0      Larry Charles
# 4     ...       0     0            1        0     0  André van Heerden
# ...   ...     ...   ...          ...      ...   ...                ...
# 6651  ...       1     0            0        0     0    Jeffrey G. Hunt
# 6652  ...       1     0            1        0     0      Blayne Weaver
# 6653  ...       1     0            0        0     0      Jae-hyun Jang
# 6654  ...       1     0            0        0     0     Cristina Jacob
# 6655  ...       1     0            0        0     0     Caryn Waechter
#
#                              Genres                       Country  \
# 0       Crime,Drama,Horror,Thriller         United States,Germany
# 1               Action,Drama,Sci-Fi         Czech Republic,Canada
# 2                  Adventure,Family                        Canada
# 3                            Comedy  United States,United Kingdom
# 4             Drama,Sci-Fi,Thriller                        Canada
# ...                             ...                           ...
# 6651            Crime,Drama,Mystery                 United States
# 6652                 Comedy,Romance                 United States
# 6653        Horror,Mystery,Thriller                   South Korea
# 6654                 Comedy,Romance                       Romania
# 6655  Drama,Horror,Mystery,Thriller                 United States
#
#             Language Runtime
# 0            English   107.0
# 1            English    92.0
# 2            English    96.0
# 3     English,German    81.0
# 4            English    95.0
# ...              ...     ...
# 6651         English    95.0
# 6652         English    90.0
# 6653          Korean   122.0
# 6654         English   109.0
# 6655         English    78.0
#
# [6656 rows x 23 columns]

# %%
#clean rating_movie_merged 
rating_table_preview= rating_movie_merged[["movie_id","IMDb","Rotten Tomatoes",]].copy()
rating_table_preview.rename(columns={"IMDb":"imdb","Rotten Tomatoes":"rotten_tomatoes"}, inplace= True)
rating_table_preview
# Out:
#       movie_id  imdb  rotten_tomatoes
# 0            2   5.1             0.03
# 1            5   3.6              NaN
# 2            6   5.5              NaN
# 3           14   6.1             0.20
# 4           19   5.0              NaN
# ...        ...   ...              ...
# 6651     43855   5.2              NaN
# 6652     43859   5.0              NaN
# 6653     43864   6.2              NaN
# 6654     43865   4.9              NaN
# 6655     43874   2.8             0.50
#
# [6656 rows x 3 columns]

# %%
#defining serial rating_id
rating_table_preview["rating_id"] = rating_table_preview.index + 1
rating_table_preview
# Out:
#       movie_id  imdb  rotten_tomatoes  rating_id
# 0            2   5.1             0.03          1
# 1            5   3.6              NaN          2
# 2            6   5.5              NaN          3
# 3           14   6.1             0.20          4
# 4           19   5.0              NaN          5
# ...        ...   ...              ...        ...
# 6651     43855   5.2              NaN       6652
# 6652     43859   5.0              NaN       6653
# 6653     43864   6.2              NaN       6654
# 6654     43865   4.9              NaN       6655
# 6655     43874   2.8             0.50       6656
#
# [6656 rows x 4 columns]

# %%
#reorganizing columns
rating_table= rating_table_preview[["rating_id","movie_id","imdb","rotten_tomatoes"]]
rating_table
# Out:
#       rating_id  movie_id  imdb  rotten_tomatoes
# 0             1         2   5.1             0.03
# 1             2         5   3.6              NaN
# 2             3         6   5.5              NaN
# 3             4        14   6.1             0.20
# 4             5        19   5.0              NaN
# ...         ...       ...   ...              ...
# 6651       6652     43855   5.2              NaN
# 6652       6653     43859   5.0              NaN
# 6653       6654     43864   6.2              NaN
# 6654       6655     43865   4.9              NaN
# 6655       6656     43874   2.8             0.50
#
# [6656 rows x 4 columns]

# %% [markdown]
# # Create Database connection

# %%
connection_string = f'{username}:{password}@localhost:5432/etl_project'
engine = create_engine(f'postgresql+psycopg2://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['movie',
#  'movie_actor',
#  'actor',
#  'lang_movie',
#  'lang',
#  'movie_genre',
#  'genre',
#  'movie_country',
#  'country',
#  'movie_drt',
#  'director',
#  'rating']

# %%
# load language table to sql
lang_table.to_sql(name='lang', con=engine, if_exists='append', index=False)

# %%
# load country table to sql
country_table.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
# load lang_movie table to sql
lang_movies_table.to_sql(name='lang_movie', con=engine, if_exists='append', index=False)

# %%
# load countr_movie table to sql
countr_movie_table.to_sql(name='movie_country', con=engine, if_exists='append', index=False)

# %%
# load rating_table to sql
rating_table.to_sql(name='rating', con=engine, if_exists='append', index=False)
