# %%
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
actors_file = "../etl_project_data/IMDb names.csv"
actors_df = pd.read_csv(actors_file)

# %%
actors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175715 entries, 0 to 175714
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   imdb_name_id           175715 non-null  object
#  1   name                   175715 non-null  object
#  2   birth_name             175715 non-null  object
#  3   height                 30080 non-null   float64
#  4   bio                    122832 non-null  object
#  5   birth_details          75229 non-null   object
#  6   birth_year             75111 non-null   float64
#  7   date_of_birth          75102 non-null   object
#  8   place_of_birth         71122 non-null   object
#  9   death_details          26862 non-null   object
#  10  death_year             26838 non-null   float64
#  11  date_of_death          26855 non-null   object
#  12  place_of_death         25036 non-null   object
#  13  reason_of_death        11972 non-null   object
#  14  spouses                175715 non-null  int64
#  15  divorces               175715 non-null  int64
#  16  spouses_with_children  175715 non-null  int64
#  17  children               175715 non-null  int64
#  18  primary_profession     175341 non-null  object
#  19  known_for_titles       174748 non-null  object
# dtypes: float64(3), int64(4), object(13)
# memory usage: 26.8+ MB

# %% [markdown]
# ### Transform premise DataFrame

# %%
# Create a filtered dataframe from specific columns

actors_cols = ["name", "birth_name", "height", "date_of_birth", "date_of_death","primary_profession"]

actors_transformed= actors_df[actors_cols].copy()

# %%
actors_transformed.head()
# Out:
#               name               birth_name  height date_of_birth  \
# 0     Fred Astaire  Frederic Austerlitz Jr.   177.0    1899-05-10
# 1    Lauren Bacall        Betty Joan Perske   174.0    1924-09-16
# 2  Brigitte Bardot          Brigitte Bardot   166.0    1934-09-28
# 3     John Belushi        John Adam Belushi   173.0    1949-01-24
# 4   Ingmar Bergman     Ernst Ingmar Bergman   179.0    1918-07-14
#
#   date_of_death              primary_profession
# 0    1987-06-22  soundtrack,actor,miscellaneous
# 1    2014-08-12              actress,soundtrack
# 2           NaN     actress,soundtrack,producer
# 3    1982-03-05         actor,writer,soundtrack
# 4    2007-07-30           writer,director,actor

# %%
# normalize profession
actorscleancsv= actors_transformed.set_index('name').primary_profession.str.split(',', expand=True).stack().reset_index('name')

# %%
# Rename the column to name
actorscleancsv = actorscleancsv.rename(columns={0:"Profession"}).copy()
actorscleancsv
# Out:
#                    name            Profession
# 0          Fred Astaire            soundtrack
# 1          Fred Astaire                 actor
# 2          Fred Astaire         miscellaneous
# 0         Lauren Bacall               actress
# 1         Lauren Bacall            soundtrack
# ..                  ...                   ...
# 0      McMagic Cardenas                 actor
# 0   Rashaduzzman Shohag  editorial_department
# 0        William Plyler              producer
# 1        William Plyler                 actor
# 2        William Plyler                writer
#
# [368477 rows x 2 columns]

# %%
#merge dataframes on "name"
actors_merge= pd.merge(actors_transformed,actorscleancsv, on="name").copy()
#actors_merge= countr_movie_merge[["movie_id","title",0]]
actors_merge.info(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 380845 entries, 0 to 380844
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                380845 non-null  object
#  1   birth_name          380845 non-null  object
#  2   height              67386 non-null   float64
#  3   date_of_birth       168817 non-null  object
#  4   date_of_death       57426 non-null   object
#  5   primary_profession  380804 non-null  object
#  6   Profession          380845 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 23.2+ MB

# %%
# Filter rows with profession as actor or actress

actors_filtered = actors_merge.loc[(actors_merge['Profession'] == "actor") | (actors_merge['Profession'] == "actress") ]
actors_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96416 entries, 1 to 380843
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                96416 non-null  object
#  1   birth_name          96416 non-null  object
#  2   height              27444 non-null  float64
#  3   date_of_birth       50802 non-null  object
#  4   date_of_death       15643 non-null  object
#  5   primary_profession  96409 non-null  object
#  6   Profession          96416 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 5.9+ MB

# %%
# Determine geneder based on profession

def gender(row):
    if row['Profession'] == "actor":
        val = "Male"
    else:
        val= "Female"
    return val
    
actors_filtered['gender'] = actors_filtered.apply(gender, axis=1)
# Out:
# <ipython-input-10-fa76204f3e38>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors_filtered['gender'] = actors_filtered.apply(gender, axis=1)

# %%
actors_clean = actors_filtered[["name", "birth_name", "height", "date_of_birth", "date_of_death", "gender"]].copy()
# renaming columns"
actors_clean= actors_clean.rename(columns={"date_of_birth":"birth_date", "date_of_death":"death_date"}).copy()

actors_clean
# Out:
#                      name               birth_name  height  birth_date  \
# 1            Fred Astaire  Frederic Austerlitz Jr.   177.0  1899-05-10
# 3           Lauren Bacall        Betty Joan Perske   174.0  1924-09-16
# 5         Brigitte Bardot          Brigitte Bardot   166.0  1934-09-28
# 8            John Belushi        John Adam Belushi   173.0  1949-01-24
# 13         Ingmar Bergman     Ernst Ingmar Bergman   179.0  1918-07-14
# ...                   ...                      ...     ...         ...
# 380830        Warisara Yu              Warisara Yu     NaN         NaN
# 380831    Apiwich Reardon          Apiwich Reardon     NaN         NaN
# 380836  Divyansha Kaushik        Divyansha Kaushik     NaN         NaN
# 380840   McMagic Cardenas         McMagic Cardenas     NaN         NaN
# 380843     William Plyler           William Plyler     NaN         NaN
#
#         death_date  gender
# 1       1987-06-22    Male
# 3       2014-08-12  Female
# 5              NaN  Female
# 8       1982-03-05    Male
# 13      2007-07-30    Male
# ...            ...     ...
# 380830         NaN  Female
# 380831         NaN    Male
# 380836         NaN  Female
# 380840         NaN    Male
# 380843         NaN    Male
#
# [96416 rows x 6 columns]

# %%
actors_clean['birth_date'] = pd.to_datetime(actors_clean['birth_date'], format='%Y-%m-%d', errors='coerce')
actors_clean['death_date'] = pd.to_datetime(actors_clean['death_date'], format='%Y-%m-%d', errors='coerce')
#actors_clean.dropna()

# %%
actors_clean.info()
#actors_clean.to_csv("../Resources/ActorsClean.csv", encoding='utf-8', index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96416 entries, 1 to 380843
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        96416 non-null  object
#  1   birth_name  96416 non-null  object
#  2   height      27444 non-null  float64
#  3   birth_date  50793 non-null  datetime64[ns]
#  4   death_date  15643 non-null  datetime64[ns]
#  5   gender      96416 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 5.1+ MB

# %% [markdown]
# ### Extract actor facebook likes from metadata csv file

# %%
# Import the metadata CSV files

metadata_file = "../etl_project_data/movie_metadata.csv"
metadata_df = pd.read_csv(metadata_file)

# %%
 ## Create a filtered dataframe from specific columns

metadata_cols = ["actor_1_name","actor_1_facebook_likes"]

metadata_transformed= metadata_df[metadata_cols].copy()

# %%
# Rename the column to name
metadata_transformed = metadata_transformed.rename(columns={"actor_1_name":"name", "actor_1_facebook_likes" : "actor_facebook_likes"}).copy()
metadata_transformed
# Out:
#                  name  actor_facebook_likes
# 0         CCH Pounder                1000.0
# 1         Johnny Depp               40000.0
# 2     Christoph Waltz               11000.0
# 3           Tom Hardy               27000.0
# 4         Doug Walker                 131.0
# ...               ...                   ...
# 5038      Eric Mabius                 637.0
# 5039      Natalie Zea                 841.0
# 5040      Eva Boehnke                   0.0
# 5041        Alan Ruck                 946.0
# 5042      John August                  86.0
#
# [5043 rows x 2 columns]

# %%
## left join to get actor facebook likes

actor_FB_merge = pd.merge(left=actors_clean, right=metadata_transformed, how='left', left_on='name', right_on='name')
actor_FB_merge
# Out:
#                     name               birth_name  height birth_date  \
# 0           Fred Astaire  Frederic Austerlitz Jr.   177.0 1899-05-10
# 1          Lauren Bacall        Betty Joan Perske   174.0 1924-09-16
# 2        Brigitte Bardot          Brigitte Bardot   166.0 1934-09-28
# 3           John Belushi        John Adam Belushi   173.0 1949-01-24
# 4           John Belushi        John Adam Belushi   173.0 1949-01-24
# ...                  ...                      ...     ...        ...
# 99592        Warisara Yu              Warisara Yu     NaN        NaT
# 99593    Apiwich Reardon          Apiwich Reardon     NaN        NaT
# 99594  Divyansha Kaushik        Divyansha Kaushik     NaN        NaT
# 99595   McMagic Cardenas         McMagic Cardenas     NaN        NaT
# 99596     William Plyler           William Plyler     NaN        NaT
#
#       death_date  gender  actor_facebook_likes
# 0     1987-06-22    Male                   NaN
# 1     2014-08-12  Female                   NaN
# 2            NaT  Female                 984.0
# 3     1982-03-05    Male                1000.0
# 4     1982-03-05    Male                1000.0
# ...          ...     ...                   ...
# 99592        NaT  Female                   NaN
# 99593        NaT    Male                   NaN
# 99594        NaT  Female                   NaN
# 99595        NaT    Male                   NaN
# 99596        NaT    Male                   NaN
#
# [99597 rows x 7 columns]

# %%
actor_FB_merge['actor_id'] = range(1, len(actor_FB_merge)+1)
actor_FB_merge.tail()
# Out:
#                     name         birth_name  height birth_date death_date  \
# 99592        Warisara Yu        Warisara Yu     NaN        NaT        NaT
# 99593    Apiwich Reardon    Apiwich Reardon     NaN        NaT        NaT
# 99594  Divyansha Kaushik  Divyansha Kaushik     NaN        NaT        NaT
# 99595   McMagic Cardenas   McMagic Cardenas     NaN        NaT        NaT
# 99596     William Plyler     William Plyler     NaN        NaT        NaT
#
#        gender  actor_facebook_likes  actor_id
# 99592  Female                   NaN     99593
# 99593    Male                   NaN     99594
# 99594  Female                   NaN     99595
# 99595    Male                   NaN     99596
# 99596    Male                   NaN     99597

# %%
#actor_FB_merge.to_csv("../Resources/actor_FB_merge.csv", encoding='utf-8', index=True)

# %% [markdown]
# # Create dataframe for Movie_actor table

# %%
# Import IMDB Movies data
xlsx_file = "../etl_project_data/IMDb movies.csv"
movies_data_df = pd.read_csv(xlsx_file)
movies_data_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
#filter data from 2000 to 2019
movies_data_df.sort_values(by=['year'], ascending=True, inplace=True)
movies_filtered= movies_data_df[~(movies_data_df['year'] < 2000)]
movies_filtered
# Out:
#       imdb_title_id                             title  \
# 32874     tt0162711                            Trixie
# 32948     tt0163983                   Bless the Child
# 35035     tt0201726                 The Last Producer
# 35036     tt0201737  Lost in the Pershing Point Hotel
# 38686     tt0279809                    Fatal Conflict
# ...             ...                               ...
# 78770     tt7246106                             Artik
# 78735     tt7225434                         Kaaviyyan
# 78707     tt7216068                      See You Soon
# 78856     tt7294400           Mirreyes contra Godinez
# 81272     tt9914286                 Sokagin Çocuklari
#
#                          original_title  year date_published  \
# 32874                            Trixie  2000     2000-08-18
# 32948                   Bless the Child  2000     2001-01-05
# 35035                 The Last Producer  2000     2000-08-22
# 35036  Lost in the Pershing Point Hotel  2000     2000-06-09
# 38686                    Fatal Conflict  2000     2000-11-10
# ...                                 ...   ...            ...
# 78770                             Artik  2019     2019-08-11
# 78735                         Kaaviyyan  2019     2019-10-18
# 78707                      See You Soon  2019     2019-07-26
# 78856           Mirreyes contra Godinez  2019     2019-01-25
# 81272                 Sokagin Çocuklari  2019     2019-03-15
#
#                         genre  duration                 country language  \
# 32874  Comedy, Crime, Mystery       116                     USA  English
# 32948    Crime, Drama, Horror       107            USA, Germany  English
# 35035           Comedy, Drama        90                     USA  English
# 35036           Comedy, Drama       107                     USA  English
# 38686   Action, Drama, Sci-Fi        92  Czech Republic, Canada  English
# ...                       ...       ...                     ...      ...
# 78770        Horror, Thriller        78                     NaN      NaN
# 78735                Thriller       109                   India    Tamil
# 78707          Drama, Romance       107                     USA  English
# 78856                  Comedy       109                  Mexico  Spanish
# 81272           Drama, Family        98                  Turkey  Turkish
#
#                        director  ...  \
# 32874              Alan Rudolph  ...
# 32948             Chuck Russell  ...
# 35035             Burt Reynolds  ...
# 35036  Julia Jay Pierrepont III  ...
# 38686          Lloyd A. Simandl  ...
# ...                         ...  ...
# 78770    Tom Botchii Skowronski  ...
# 78735                   Sarathy  ...
# 78707          David Mahmoudieh  ...
# 78856              Chava Cartas  ...
# 81272         Ahmet Faik Akinci  ...
#
#                                                   actors  \
# 32874  Emily Watson, Dermot Mulroney, Nick Nolte, Nat...
# 32948  Kim Basinger, Jimmy Smits, Holliston Coleman, ...
# 35035  Sean Astin, David Atkinson, Leslie Bega, Benja...
# 35036  Leslie Jordan, Erin Chandler, Mark Pellegrino,...
# 38686  Kari Wuhrer, Jennifer Rubin, Leo Rossi, Miles ...
# ...                                                  ...
# 78770  Chase Williamson, Jerry G. Angelo, Lauren Ashl...
# 78735         L. Srinath, Athmeeya Rajan, Shaam, Sridevi
# 78707  Harvey Keitel, Liam McIntyre, Poppy Drayton, O...
# 78856  Diana Bovio, Pablo Lyle, Roberto Aguire, Danie...
# 81272  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
#
#                                              description avg_vote  votes  \
# 32874  An eccentric, unconventional woman whose naive...      5.0   1376
# 32948  Cody, a little girl abandoned by her mother an...      5.1  13440
# 35035  An old-time mogul struggles to reenter the clu...      4.7    265
# 35036  Taken from the life story of Leslie Jordan. A ...      4.5    161
# 38686  An ex-star pilot must stop a mad criminal and ...      3.6    220
# ...                                                  ...      ...    ...
# 78770  A comic book obsessed serial killer teaches hi...      4.0    283
# 78735  While in the US for training, Tamil Nadu cop A...      5.6    128
# 78707  A U.S. soccer star suffers a career-threatenin...      4.7    265
# 78856  Tells the story of Genaro Rodríguez, a young g...      5.2    846
# 81272                                                NaN      7.2    190
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 32874           NaN          $ 295683              $ 295683      26.0
# 32948    $ 65000000        $ 29381494            $ 40443010      17.0
# 35035           NaN               NaN                   NaN       NaN
# 35036           NaN               NaN                   NaN       NaN
# 38686           NaN               NaN                   NaN       NaN
# ...             ...               ...                   ...       ...
# 78770           NaN               NaN                   NaN       NaN
# 78735           NaN               NaN                   NaN       NaN
# 78707           NaN               NaN              $ 277126      29.0
# 78856  MXN 28000000               NaN            $ 11940579       NaN
# 81272           NaN               NaN                $ 2833       NaN
#
#       reviews_from_users  reviews_from_critics
# 32874               35.0                  37.0
# 32948              193.0                 103.0
# 35035                9.0                   3.0
# 35036                2.0                   2.0
# 38686                5.0                   5.0
# ...                  ...                   ...
# 78770               16.0                  20.0
# 78735              105.0                   1.0
# 78707                4.0                   3.0
# 78856                4.0                   1.0
# 81272                NaN                   NaN
#
# [43881 rows x 22 columns]

# %%
# Create a filtered dataframe from specific columns
actormovie_cols = ["imdb_title_id", "title", "actors"]

actormovie_transformed= movies_filtered[actormovie_cols].copy()

actormovie_transformed.head()
# Out:
#       imdb_title_id                             title  \
# 32874     tt0162711                            Trixie
# 32948     tt0163983                   Bless the Child
# 35035     tt0201726                 The Last Producer
# 35036     tt0201737  Lost in the Pershing Point Hotel
# 38686     tt0279809                    Fatal Conflict
#
#                                                   actors
# 32874  Emily Watson, Dermot Mulroney, Nick Nolte, Nat...
# 32948  Kim Basinger, Jimmy Smits, Holliston Coleman, ...
# 35035  Sean Astin, David Atkinson, Leslie Bega, Benja...
# 35036  Leslie Jordan, Erin Chandler, Mark Pellegrino,...
# 38686  Kari Wuhrer, Jennifer Rubin, Leo Rossi, Miles ...

# %%
# Comma separated value in the column transform into multiple rows

actormoviecleancsv= actormovie_transformed.set_index('imdb_title_id').actors.str.split(', ', expand=True).stack().reset_index('imdb_title_id')
actormoviecleancsv.head()
# Out:
#   imdb_title_id                0
# 0     tt0162711     Emily Watson
# 1     tt0162711  Dermot Mulroney
# 2     tt0162711       Nick Nolte
# 3     tt0162711      Nathan Lane
# 4     tt0162711  Brittany Murphy

# %%
actormoviecleancsv.info()
#actormoviecleancsv.to_csv("../Resources/ActorMovieClean.csv", encoding='utf-8', index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 591357 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   imdb_title_id  591357 non-null  object
#  1   0              591357 non-null  object
# dtypes: object(2)
# memory usage: 13.5+ MB

# %%
# Rename column name

actormovie_renamed= actormoviecleancsv.rename(columns={0:"name"}).copy()


actormovie_renamed
# Out:
#    imdb_title_id             name
# 0      tt0162711     Emily Watson
# 1      tt0162711  Dermot Mulroney
# 2      tt0162711       Nick Nolte
# 3      tt0162711      Nathan Lane
# 4      tt0162711  Brittany Murphy
# ..           ...              ...
# 10     tt9914286     Arcan Bunial
# 11     tt9914286   Seval Hislisoy
# 12     tt9914286  Ergül Çolakoglu
# 13     tt9914286      Gülçin Ugur
# 14     tt9914286  Ibrahim Balaban
#
# [591357 rows x 2 columns]

# %%
# merge with actor table table to get actor ID 

actormovie_merge= pd.merge(actormovie_renamed,actor_FB_merge, on="name")
actormovie_merge
# Out:
#        imdb_title_id                name             birth_name  height  \
# 0          tt0162711        Emily Watson  Emily Margaret Watson   173.0
# 1          tt0162711        Emily Watson  Emily Margaret Watson   173.0
# 2          tt0162711        Emily Watson  Emily Margaret Watson   173.0
# 3          tt0162711        Emily Watson  Emily Margaret Watson   173.0
# 4          tt0211492        Emily Watson  Emily Margaret Watson   173.0
# ...              ...                 ...                    ...     ...
# 388776     tt7272948     Scarlett Davies        Scarlett Davies     NaN
# 388777     tt7272948         Maria Louis            Maria Louis     NaN
# 388778     tt7262990  Kherrington Briggs     Kherrington Briggs     NaN
# 388779     tt7262990        Mai Brunelle           Mai Brunelle   200.0
# 388780     tt7255568       Ananya Panday          Ananya Panday   200.0
#
#        birth_date death_date  gender  actor_facebook_likes  actor_id
# 0      1967-01-14        NaT  Female                 876.0      3208
# 1      1967-01-14        NaT  Female                 876.0      3209
# 2      1967-01-14        NaT  Female                 876.0      3210
# 3      1967-01-14        NaT  Female                 876.0      3211
# 4      1967-01-14        NaT  Female                 876.0      3208
# ...           ...        ...     ...                   ...       ...
# 388776        NaT        NaT  Female                   NaN     98880
# 388777        NaT        NaT  Female                   NaN     91322
# 388778        NaT        NaT  Female                   NaN     98952
# 388779        NaT        NaT  Female                   NaN     96079
# 388780        NaT        NaT  Female                   NaN     98867
#
# [388781 rows x 9 columns]

# %%
actormovie_merge.drop(['birth_name', 'height', 'birth_date', 'death_date', 'actor_facebook_likes'], axis=1, inplace=True)
actormovie_merge
# Out:
#        imdb_title_id                name  gender  actor_id
# 0          tt0162711        Emily Watson  Female      3208
# 1          tt0162711        Emily Watson  Female      3209
# 2          tt0162711        Emily Watson  Female      3210
# 3          tt0162711        Emily Watson  Female      3211
# 4          tt0211492        Emily Watson  Female      3208
# ...              ...                 ...     ...       ...
# 388776     tt7272948     Scarlett Davies  Female     98880
# 388777     tt7272948         Maria Louis  Female     91322
# 388778     tt7262990  Kherrington Briggs  Female     98952
# 388779     tt7262990        Mai Brunelle  Female     96079
# 388780     tt7255568       Ananya Panday  Female     98867
#
# [388781 rows x 4 columns]

# %%
#actormovie_merge.to_csv("../Resources/actormovie_merge.csv", encoding='utf-8', index=True)

# %% [markdown]
# ### Create database connection

# %%
connection_string = f'{username}:{password}@localhost:5432/etl_project'
engine = create_engine(f'postgresql://{connection_string}')

# %%
select_imdb_movies_df = pd.read_sql_query('select * from "movie"',con=engine)

# %%
## Extract data from movies table

#select_imdb_movies_df = pd.read_csv("../Resources/movie_output.csv")
select_imdb_movies_df.head()
# Out:
#    movie_id                             title  year  duration      budget  \
# 0         1                            Trixie  2000       116         NaN
# 1         2                   Bless the Child  2000       107  65000000.0
# 2         3                 The Last Producer  2000        90         NaN
# 3         4  Lost in the Pershing Point Hotel  2000       107         NaN
# 4         5                    Fatal Conflict  2000        92         NaN
#
#    worlwide_gross_income  netflix   hulu  prime  disney imdb_title_id
# 0               295683.0    False  False  False   False     tt0162711
# 1             40443010.0    False  False   True   False     tt0163983
# 2                    NaN    False  False  False   False     tt0201726
# 3                    NaN    False  False  False   False     tt0201737
# 4                    NaN    False  False   True   False     tt0279809

# %%
#merge dataframes on "IMDB title id"
actormovie_final= pd.merge(select_imdb_movies_df,actormovie_merge, on="imdb_title_id").copy()
actormovie_final
# Out:
#         movie_id              title  year  duration  budget  \
# 0              1             Trixie  2000       116     NaN
# 1              1             Trixie  2000       116     NaN
# 2              1             Trixie  2000       116     NaN
# 3              1             Trixie  2000       116     NaN
# 4              1             Trixie  2000       116     NaN
# ...          ...                ...   ...       ...     ...
# 388776     43881  Sokagin Çocuklari  2019        98     NaN
# 388777     43881  Sokagin Çocuklari  2019        98     NaN
# 388778     43881  Sokagin Çocuklari  2019        98     NaN
# 388779     43881  Sokagin Çocuklari  2019        98     NaN
# 388780     43881  Sokagin Çocuklari  2019        98     NaN
#
#         worlwide_gross_income  netflix   hulu  prime  disney imdb_title_id  \
# 0                    295683.0    False  False  False   False     tt0162711
# 1                    295683.0    False  False  False   False     tt0162711
# 2                    295683.0    False  False  False   False     tt0162711
# 3                    295683.0    False  False  False   False     tt0162711
# 4                    295683.0    False  False  False   False     tt0162711
# ...                       ...      ...    ...    ...     ...           ...
# 388776                 2833.0    False  False  False   False     tt9914286
# 388777                 2833.0    False  False  False   False     tt9914286
# 388778                 2833.0    False  False  False   False     tt9914286
# 388779                 2833.0    False  False  False   False     tt9914286
# 388780                 2833.0    False  False  False   False     tt9914286
#
#                    name  gender  actor_id
# 0          Emily Watson  Female      3208
# 1          Emily Watson  Female      3209
# 2          Emily Watson  Female      3210
# 3          Emily Watson  Female      3211
# 4       Dermot Mulroney    Male      1604
# ...                 ...     ...       ...
# 388776      Orhan Aydin    Male     58505
# 388777      Orhan Aydin    Male     58506
# 388778      Orhan Aydin    Male     58507
# 388779      Orhan Aydin    Male     58508
# 388780      Toygun Ates    Male     60202
#
# [388781 rows x 14 columns]

# %%
actormovie_final= actormovie_final[["movie_id","actor_id"]]

# %%
actormovie_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388781 entries, 0 to 388780
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   movie_id  388781 non-null  int64
#  1   actor_id  388781 non-null  int32
# dtypes: int32(1), int64(1)
# memory usage: 7.4 MB

# %%
# Confirm tables
engine.table_names()
# Out:
# ['movie',
#  'movie_actor',
#  'actor',
#  'lang_movie',
#  'lang',
#  'movie_genre',
#  'genre',
#  'movie_country',
#  'country',
#  'movie_drt',
#  'director',
#  'rating']

# %% [markdown]
# ### Load DataFrames into database

# %%
actor_FB_merge.to_sql(name='actor', con=engine, if_exists='append', index=False)

# %%
actormovie_final.to_sql(name='movie_actor', con=engine, if_exists='append', index=False)
